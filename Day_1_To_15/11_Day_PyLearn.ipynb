# %%
print('Trust The Process\nThis is Day-11\nToday we will make a blackjack game (21) :)')
# Out:
# Trust The Process
# This is Day-11
# Today we will make a blackjack game (21) :)

# %%
############### Blackjack Project Hints #####################

#Difficulty Normal 😎: Use all Hints below to complete the project.
#Difficulty Hard 🤔: Use only Hints 1, 2, 3 to complete the project.
#Difficulty Extra Hard 😭: Only use Hints 1 & 2 to complete the project.
#Difficulty Expert 🤯: Only use Hint 1 to complete the project.

############### Our Blackjack House Rules #####################

## The deck is unlimited in size. 
## There are no jokers. 
## The Jack/Queen/King all count as 10.
## The the Ace can count as 11 or 1.
## Use the following list as the deck of cards:
## cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
## The cards in the list have equal probability of being drawn.
## Cards are not removed from the deck as they are drawn.
## The computer is the dealer.

##################### Hints #####################

#Hint 1: Go to this website and try out the Blackjack game: 
#   https://games.washingtonpost.com/games/blackjack/
#Then try out the completed Blackjack project here: 
#   http://blackjack-final.appbrewery.repl.run

#Hint 2: Read this breakdown of program requirements: 
#   http://listmoz.com/view/6h34DJpvJBFVRlZfJvxF
#Then try to create your own flowchart for the program.

#Hint 3: Download and read this flow chart I've created: 
#   https://drive.google.com/uc?export=download&id=1rDkiHCrhaf9eX7u7yjM1qwSuyEk-rPnt

#Hint 4: Create a deal_card() function that uses the List below to *return* a random card.
#11 is the Ace.
#cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]

#Hint 5: Deal the user and computer 2 cards each using deal_card() and append().
#user_cards = []
#computer_cards = []

#Hint 6: Create a function called calculate_score() that takes a List of cards as input 
#and returns the score. 
#Look up the sum() function to help you do this.

#Hint 7: Inside calculate_score() check for a blackjack (a hand with only 2 cards: ace + 10) and return 0 instead of the actual score. 0 will represent a blackjack in our game.

#Hint 8: Inside calculate_score() check for an 11 (ace). If the score is already over 21, remove the 11 and replace it with a 1. You might need to look up append() and remove().

#Hint 9: Call calculate_score(). If the computer or the user has a blackjack (0) or if the user's score is over 21, then the game ends.

#Hint 10: If the game has not ended, ask the user if they want to draw another card. If yes, then use the deal_card() function to add another card to the user_cards List. If no, then the game has ended.

#Hint 11: The score will need to be rechecked with every new card drawn and the checks in Hint 9 need to be repeated until the game ends.

#Hint 12: Once the user is done, it's time to let the computer play. The computer should keep drawing cards as long as it has a score less than 17.

#Hint 13: Create a function called compare() and pass in the user_score and computer_score. If the computer and user both have the same score, then it's a draw. If the computer has a blackjack (0), then the user loses. If the user has a blackjack (0), then the user wins. If the user_score is over 21, then the user loses. If the computer_score is over 21, then the computer loses. If none of the above, then the player with the highest score wins.

#Hint 14: Ask the user if they want to restart the game. If they answer yes, clear the console and start a new game of blackjack and show the logo from art.py.

# %%
#Blackjack
import random
# user_cards=[]
# comp_cards=[]


cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
#use random function to chose a card

def first_hand():
    random_2_cards=random.sample(cards,2)
    return random_2_cards

def next_card():
    random_card3=random.choice(cards)
    return random_card3

def another_card_check():
    new_card_check=input("Type 'y' to get another card, type 'n' to pass: ")
    if new_card_check.lower()=='y':
        return True
    else:
        return False

def check_who_wins(): 
    if user_score>21:
        print('You went over, Computer Wins')
    if comp_score>21:
        print('Comp went over, You Win')
    else:
        if comp_score<user_score:
            print('You Win')
        elif comp_score>user_score:
            print('Comp Wins')
        elif comp_score == user_score:
            print('It is a draw')
        

def has_21_blackjack():
    if user_score==21:
        print(f'Your cards: {user_cards}, User current score: {user_score}' )
        print('You have blackjack, You won')
        return True
    elif comp_score==21:
        print(f'Your cards: {user_cards}, User current score: {user_score}' )
        print('Computer has blackjack, Comp Wins')
        return True
    
def blackjack():
    wanna_play=input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
    global user_score, comp_score,user_cards,comp_cards
    user_score=0
    comp_score=0

    if wanna_play.lower()=='y':
        
        user_cards = first_hand()
        for card in user_cards:
            user_score += card
        print(f'Your cards: {user_cards}, User current score: {user_score}' )

        comp_cards = first_hand()
        for card in comp_cards:
            comp_score += card
        print(f'Computer first card: {comp_cards[0]}')
        
        if not has_21_blackjack():
            #All logic goes here       
            if user_score>21:
                if 11 in user_cards:
                    index = user_cards.index(11)
                    user_cards[index] = 1
                    if sum(user_cards)>21:
                        print('You Lose')
                    else:
                        another_card_check()
                else:
                    print('You Lose')       
            else:
                if another_card_check():
                    print(f'Your cards were {user_cards}, Comp cards{comp_cards}')
                    user_cards.append(next_card())
                    comp_cards.append(next_card())
                    comp_score =sum(comp_cards)
                    user_score =sum(user_cards)
                    print(f'Your updated cards {user_cards}, Comp cards{comp_cards}')
                    print(f'Updated User score {user_score}')
                    print(f'Updated Comp score {comp_score}')
                    check_who_wins()
                else:
                    print(f'Your cards were {user_cards}, Comp cards{comp_cards}')
                    if comp_score<17:
                        print('Computer Plays')
                        comp_score += next_card()
                        if comp_score>21:
                            print('You Win')
                        else:
                            check_who_wins()
                    else:
                        check_who_wins()
                        
    else:
        print('Thank you, have a nice day')


#first_hand()
#next_card
blackjack()
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n': y
# Your cards: [4, 11], User current score: 15
# Computer first card: 10
# Entered in user score <21 area
# Type 'y' to get another card, type 'n' to pass: y
# Your cards were [4, 11], Comp cards[10, 9]
# Your cards [4, 11, 5], Comp cards[10, 9, 7]
# Updated User score 20
# Updated Comp score 26
# Reached in check_who_wins
# User score 20
# Comp score 26
# User Wins
# Comp Wins

# %%
#make additional changes now
import random
# user_cards=[]
# comp_cards=[]


cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
#use random function to chose a card

def first_hand():
    random_2_cards=random.sample(cards,2)
    return random_2_cards

def next_card():
    random_card3=random.choice(cards)
    return random_card3

def another_card_check():
    new_card_check=input("Type 'y' to get another card, type 'n' to pass: ")
    if new_card_check.lower()=='y':
        return True
    else:
        return False

def check_who_wins(): 
    if user_score>21:
        print('You went over, Computer Wins :(')
    if comp_score>21:
        print('Comp went over, You Win :)')
    else:
        if comp_score<user_score:
            print('You Win')
        elif comp_score>user_score:
            print('Comp Wins')
        elif comp_score == user_score:
            print('It is a draw')
        

def has_21_blackjack():
    if user_score==21:
        print(f'Your cards: {user_cards}, User current score: {user_score}' )
        print('You have blackjack, You won')
        return True
    elif comp_score==21:
        print(f'Your cards: {user_cards}, User current score: {user_score}' )
        print('Computer has blackjack, Comp Wins')
        return True
    
def blackjack():
    wanna_play=input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
    global user_score, comp_score,user_cards,comp_cards
    user_score=0
    comp_score=0

    if wanna_play.lower()=='y':
        
        user_cards = first_hand()
        for card in user_cards:
            user_score += card
        print(f'Your cards: {user_cards}, User current score: {user_score}' )

        comp_cards = first_hand()
        for card in comp_cards:
            comp_score += card
        print(f'Computer first card: {comp_cards[0]}')
        
        if not has_21_blackjack():
            #All logic goes here       
            if user_score>21:
                if 11 in user_cards:
                    index = user_cards.index(11)
                    user_cards[index] = 1
                    if sum(user_cards)>21:
                        print('You Lose')
                    else:
                        another_card_check()
                else:
                    print('You Lose')       
            else:
                if another_card_check():
                    print(f'Your cards were {user_cards}, Comp cards{comp_cards}')
                    user_cards.append(next_card())
                    comp_cards.append(next_card())
                    comp_score =sum(comp_cards)
                    user_score =sum(user_cards)
                    print(f'Your updated cards {user_cards}, Comp cards{comp_cards}')
                    print(f'Updated User score {user_score}')
                    print(f'Updated Comp score {comp_score}')
                    check_who_wins()
                else:
                    print(f'Your cards were {user_cards}, Comp cards{comp_cards}')
                    if comp_score<17:
                        print('Computer Plays')
                        comp_score += next_card()
                        if comp_score>21:
                            print('You Win')
                        else:
                            check_who_wins()
                    else:
                        check_who_wins()
                        
    else:
        print('Thank you, have a nice day')


#first_hand()
#next_card
blackjack()
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n': y
# Your cards: [6, 3], User current score: 9
# Computer first card: 4
# Type 'y' to get another card, type 'n' to pass: y
# Your cards were [6, 3], Comp cards[4, 11]
# Your updated cards [6, 3, 2], Comp cards[4, 11, 9]
# Updated User score 11
# Updated Comp score 24
# Comp went over, You Win :)

# %%
#Blackjack
import random
import os


cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
#use random function to chose a card

def first_hand():
    random_2_cards=[]
    random_2_cards=random.sample(cards,2)
    return random_2_cards

def next_card():
    random_card3=[]
    random_card3=random.choice(cards)
    return random_card3

def another_card_check():
    new_card_check=input("Type 'y' to get another card, type 'n' to pass: ")
    if new_card_check.lower()=='y':
        return True
    else:
        return False

def check_who_wins(): 
    if user_score>21:
        print('You went over, Computer Wins :(')
    if comp_score>21:
        print('Comp went over, You Win :)')
    else:
        if comp_score<user_score:
            print('You Win')
        elif comp_score>user_score:
            print('Comp Wins')
        elif comp_score == user_score:
            print('It is a draw')
        

def has_21_blackjack():
    if user_score==21:
        print(f'Your cards: {user_cards}, User current score: {user_score}' )
        print('You have blackjack, You won')
        return True
    elif comp_score==21:
        print(f'Your cards: {user_cards}, User current score: {user_score}' )
        print('Computer has blackjack, Comp Wins')
        return True

    
def wanna_play():
    wanna_play_check=input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
    if wanna_play_check.lower()=='y':
        os.system('cls' if os.name == 'nt' else 'clear')
        user_score=0
        comp_score=0
        return True
    else:
        return False


def blackjack():
    global user_score, comp_score,user_cards,comp_cards
    #user_score=0
    #comp_score=0

    while wanna_play():
        #reseting values
        user_score=0
        comp_score=0
        
        user_cards = first_hand()
        for card in user_cards:
            user_score += card
        print(f'Your cards: {user_cards}, User current score: {user_score}' )

        comp_cards = first_hand()
        for card in comp_cards:
            comp_score += card
        print(f'Computer first card: {comp_cards[0]}')
        
        if not has_21_blackjack():
            #All logic goes here       
            if user_score>21:
                if 11 in user_cards:
                    index = user_cards.index(11)
                    user_cards[index] = 1
                    if sum(user_cards)>21:
                        print('You Lose')
                    else:
                        another_card_check()
                else:
                    print('You Lose')       
            else:
                if another_card_check():
                    print(f'Your cards were {user_cards}, Comp cards{comp_cards}')
                    user_cards.append(next_card())
                    comp_cards.append(next_card())
                    comp_score =sum(comp_cards)
                    user_score =sum(user_cards)
                    print(f'Your updated cards {user_cards}, Comp cards{comp_cards}')
                    print(f'Updated User score {user_score}')
                    print(f'Updated Comp score {comp_score}')
                    check_who_wins()
                else:
                    print(f'Your cards were {user_cards}, Comp cards{comp_cards}')
                    if comp_score<17:
                        print('Computer Plays')
                        comp_score += next_card()
                        if comp_score>21:
                            print('You Win')
                        else:
                            check_who_wins()
                    else:
                        check_who_wins()
                        
    else:
        print('Thank you, have a nice day')


#first_hand()
#next_card
blackjack()
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n': y
# Your cards: [11, 10], User current score: 21
# Computer first card: 6
# Your cards: [11, 10], User current score: 21
# You have blackjack, You won
# Do you want to play a game of Blackjack? Type 'y' or 'n': y
# Your cards: [8, 4], User current score: 12
# Computer first card: 2
# Type 'y' to get another card, type 'n' to pass: y
# Your cards were [8, 4], Comp cards[2, 4]
# Your updated cards [8, 4, 6], Comp cards[2, 4, 7]
# Updated User score 18
# Updated Comp score 13
# You Win
# Do you want to play a game of Blackjack? Type 'y' or 'n': y
# Your cards: [10, 7], User current score: 17
# Computer first card: 10
# Type 'y' to get another card, type 'n' to pass: y
# Your cards were [10, 7], Comp cards[10, 2]
# Your updated cards [10, 7, 6], Comp cards[10, 2, 5]
# Updated User score 23
# Updated Comp score 17
# You went over, Computer Wins :(
# You Win
# Do you want to play a game of Blackjack? Type 'y' or 'n': y
# ...

# %%
print('Trust The Process\nHuraah!!! Day-11 Completed')
# Out:
# Trust The Process
# Huraah!!! Day-11 Completed

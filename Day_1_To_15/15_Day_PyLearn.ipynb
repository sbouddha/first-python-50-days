# %%
print('Trust The Process\nWelcome to Day-15')
print('Now we are entering Intermediate Zone')
print('That means, now we are learning to walk and then will learn to run, so keep up the hard work')
# Out:
# Trust The Process
# Welcome to Day-15
# Now we are entering Intermediate Zone
# That means, now we are learning to walk and then will learn to run, so keep up the hard work

# %%
#Coffe Machine Project

MENU = {
    "espresso": {
        "ingredients": {
            "water": 50,
            "milk" : 0,
            "coffee": 18,
        },
        "cost": 1.5,
    },
    "latte": {
        "ingredients": {
            "water": 200,
            "milk": 150,
            "coffee": 24,
        },
        "cost": 2.5,
    },
    "cappuccino": {
        "ingredients": {
            "water": 250,
            "milk": 100,
            "coffee": 24,
        },
        "cost": 3.0,
    }
}

resources = {
    "water": 300,
    "milk": 200,
    "coffee": 100,
}


refund_amount=0
tota_user_coin_value=0
money_required=0
is_on=True

def required_resources_check():
    print(resources)
    global water_required,milk_required,coffee_required
    #Available Check
    water_available  = resources['water']
    milk_available   = resources['milk']
    coffee_available = resources['coffee']
    #Need check
    if coffe_input in MENU:
        water_required  =MENU[coffe_input]["ingredients"]['water']
        milk_required   =MENU[coffe_input]["ingredients"]['milk']
        coffee_required =MENU[coffe_input]["ingredients"]['coffee']
    #Requirement check
    if (water_available>=water_required) and (milk_available>=milk_required) and (coffee_available>=coffee_required):
        return True
    else:
        False

    
def user_input_money():
    global tota_user_coin_value
    print('Please insert coins.')
    quarters=int(input('how many quarters?: '))
    dimes=int(input('how many dimes?: '))
    nickles=int(input('how many nickles?: '))
    pennies=int(input('how many pennies?: '))
    tota_user_coin_value=float( (0.25*quarters) + (0.1*dimes) + (0.05*nickles) + (0.01*pennies) )
    return tota_user_coin_value

def money_check():
    global money_required
    money_required  = MENU[coffe_input]["cost"]
    if user_input_money()>=money_required:
        return True
    else:
        print('Sorry that is not enough money. Money refunded')
        return False


def update_resource():
    print('Updating resource after coffe taken')
    resources['water']  = resources['water'] - water_required
    resources['milk']   = resources['milk'] - milk_required
    resources['coffee'] = resources['coffee'] - coffee_required
    print(resources)
    

def remaining_money():
    global refund_amount
    refund_amount=tota_user_coin_value-money_required
    return refund_amount

    
def front_end():
    global coffe_input
    coffe_input=input('What would you like? (espresso/latte/cappuccino): ')

    
while is_on:
    front_end()
    if coffe_input=='off':
        print('Machine Turned Off ')
        is_on=False
    elif coffe_input=='report':
        for key,value in resources.items():
            print(key, ':' , value)
    else:
        if money_check():
            if required_resources_check():
                print(f'Here is your {coffe_input} ☕️ Enjoy!!!')
                remaining_money()
                print(f'Here is $ {refund_amount} in change')
                update_resource()
# Out:
# What would you like? (espresso/latte/cappuccino): latte
# Please insert coins.
# how many quarters?: 2
# how many dimes?: 2
# how many nickles?: 2
# how many pennies?: 2
# Sorry that is not enough money. Money refunded
# What would you like? (espresso/latte/cappuccino): latte
# Please insert coins.
# how many quarters?: 2
# how many dimes?: 50
# how many nickles?: 25
# how many pennies?: 25
# {'water': 300, 'milk': 200, 'coffee': 100}
# Here is your latte ☕️ Enjoy!!!
# Here is $ 4.5 in change
# Updating resource after coffe taken
# {'water': 100, 'milk': 50, 'coffee': 76}
# What would you like? (espresso/latte/cappuccino): off
# Machine Turned Off

# %%
#Angela Code

MENU = {
    "espresso": {
        "ingredients": {
            "water": 50,
            "coffee": 18,
        },
        "cost": 1.5,
    },
    "latte": {
        "ingredients": {
            "water": 200,
            "milk": 150,
            "coffee": 24,
        },
        "cost": 2.5,
    },
    "cappuccino": {
        "ingredients": {
            "water": 250,
            "milk": 100,
            "coffee": 24,
        },
        "cost": 3.0,
    }
}

profit = 0
resources = {
    "water": 300,
    "milk": 200,
    "coffee": 100,
}


def is_resource_sufficient(order_ingredients):
    """Returns True when order can be made, False if ingredients are insufficient."""
    for item in order_ingredients:
        if order_ingredients[item] > resources[item]:
            print(f"​Sorry there is not enough {item}.")
            return False
    return True


def process_coins():
    """Returns the total calculated from coins inserted."""
    print("Please insert coins.")
    total = int(input("how many quarters?: ")) * 0.25
    total += int(input("how many dimes?: ")) * 0.1
    total += int(input("how many nickles?: ")) * 0.05
    total += int(input("how many pennies?: ")) * 0.01
    return total


def is_transaction_successful(money_received, drink_cost):
    """Return True when the payment is accepted, or False if money is insufficient."""
    if money_received >= drink_cost:
        change = round(money_received - drink_cost, 2)
        print(f"Here is ${change} in change.")
        global profit
        profit += drink_cost
        return True
    else:
        print("Sorry that's not enough money. Money refunded.")
        return False


def make_coffee(drink_name, order_ingredients):
    """Deduct the required ingredients from the resources."""
    for item in order_ingredients:
        resources[item] -= order_ingredients[item]
    print(f"Here is your {drink_name} ☕️. Enjoy!")


is_on = True

while is_on:
    choice = input("​What would you like? (espresso/latte/cappuccino): ")
    if choice == "off":
        is_on = False
    elif choice == "report":
        print(f"Water: {resources['water']}ml")
        print(f"Milk: {resources['milk']}ml")
        print(f"Coffee: {resources['coffee']}g")
        print(f"Money: ${profit}")
    else:
        drink = MENU[choice]
        if is_resource_sufficient(drink["ingredients"]):
            payment = process_coins()
            if is_transaction_successful(payment, drink["cost"]):
                make_coffee(choice, drink["ingredients"])
# Out:
# ​What would you like? (espresso/latte/cappuccino): latte
# Please insert coins.
# how many quarters?: 2
# how many dimes?: 50
# how many nickles?: 25
# how many pennies?: 25
# Here is $4.5 in change.
# Here is your latte ☕️. Enjoy!
# ​What would you like? (espresso/latte/cappuccino): off

# %%
#Code check
drink = MENU['latte']
print(drink)
# Out:
# {'ingredients': {'water': 200, 'milk': 150, 'coffee': 24}, 'cost': 2.5}

# %%
print('Trust the process')
print('I can see that I can write the code, which can get the job done, but have to enhace the approachability')
print('Hurrah!!! Day-15 Completed')
# Out:
# Trust the process
# I can see that I can write the code, which can get the job done, but have to enhace the approachability
# Hurrah!!! Day-15 Completed
